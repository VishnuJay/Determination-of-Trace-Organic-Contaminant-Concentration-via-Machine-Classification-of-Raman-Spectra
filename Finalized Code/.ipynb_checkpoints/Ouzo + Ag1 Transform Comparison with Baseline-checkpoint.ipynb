# %%
import pandas as pd
import numpy as np
from scipy import stats as stats
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import Perceptron
from sklearn.svm import LinearSVC
from sklearn.neighbors import KNeighborsClassifier
import KeyFunctions as me

# %%
#Get Evaporating Ouzo Data
concs = ['10-5', '10-9', '10-11', '10-14', '10-16']
dfO = me.GetFolderSpectra("ESMA", "r6g(Evap Ouzo)", concs)
col_names = np.array(dfO.columns)

# %%
#Get and Process Ag Rings Data
from scipy import signal

Source = "ESMA"
Chemical = "r6g(Ag Nano Rings)"

dfA1 = pd.DataFrame()
for j in [6,9]:
    Concentration = "10-" + str(j)
    for i in [1, 2, 3, 4, 5]:
        temp = me.GetSpectra(Source, Chemical, Concentration, str(i))
        temp.set_index("#Wave", inplace = True)
        targ_len = len(temp)
        temp = temp.transpose()
        temp = temp.rename({'#Intensity':Concentration}, axis = 0)
        temp.set_axis(np.array(range(targ_len)), axis =1, inplace = True)
        dfA1 = pd.concat([dfA1, temp], axis = 0)  
        
for j in [5,7,8]:
    Concentration = "10-" + str(j)
    for i in [1, 2, 3, 4, 5]:
        temp = me.GetSpectra(Source, Chemical, Concentration, str(i))
        temp.set_index("#Wave", inplace = True)
        temp = np.flip(signal.resample(temp, targ_len))
        temp = np.reshape(temp, [targ_len])
        temp = pd.DataFrame(temp)
        temp = temp.transpose()
        temp = temp.rename({0:Concentration}, axis = 0)
        temp.set_axis(np.array(range(targ_len)), axis =1, inplace = True)
        dfA1 = pd.concat([dfA1, temp], axis = 0) 
        
dfA1.set_axis(col_names, axis =1, inplace = True)
dfA1
# Out:
#       1800.529297   1798.058594   1795.587891   1793.115234   1790.642578  \
# 10-6 -1703.744740   -117.852180   -194.875670    601.174620    146.925890
# 10-6  -981.582770   -225.369400  -1710.623880    488.973420  -1798.426070
# 10-6 -1372.311570   -731.729060     55.581100    178.137950     -7.581610
# 10-6  -727.042280   1451.406650  -1125.559850    569.099440    326.681400
# 10-6   578.263611    672.665649   -433.932922     85.725266   -123.281952
# 10-9    19.240747     20.888121    -34.208870    -16.341410    -17.179741
# 10-9    50.573162    -54.407650     44.640884    -22.775305     11.480504
# 10-9    -7.783530    -11.804660      3.845780      7.272230      3.261630
# 10-9     9.932826      6.339216    -59.517483     13.662543     49.276421
# 10-9    29.230590     46.700890     26.337960    -23.409800    -24.946150
# 10-5  1464.891001  11358.734903  16740.589541  22628.453214  25721.880372
# 10-5 -1564.654216   3435.788304   3732.020394   6680.359355  10658.547081
# 10-5   844.172560   5382.262723   6903.332582  10370.199417  15624.124203
# 10-5   694.736302   7292.396919   9824.627041  12647.853968  16169.739715
# 10-5   336.794897   4753.506271   5580.841708   8268.559538  10283.185372
# 10-7  -236.361771    764.938279    885.953885    502.429867   -291.379843
# 10-7  -122.593278   1508.456226   2069.143397   1742.768286    401.301802
# 10-7 -1118.964846   -344.165868   -245.862156   -220.790771  -1124.945940
# 10-7  -187.916604   1549.037019   2225.037445   3080.341376   2390.224631
# 10-7  -749.452232    474.964784   1039.872214   1570.713217    158.723666
# 10-8   301.418033   1442.423924   2178.097670   2794.853224   2850.916846
# 10-8   222.536815   1068.941329   1836.016403   2366.874874   2623.682872
# 10-8   524.139086   2807.135792   3892.190365   4825.359264   5439.767085
# 10-8   131.491796    528.076084    715.131470    879.057949    936.171804
# 10-8    95.424392    711.256444   1033.207272   1227.835535   1301.753283
#
#        1788.169922   1785.697266   1783.222656   1780.746094  1778.269531  \
# 10-6    537.876900    184.584450    110.133810   1326.333490 -1548.287300
# 10-6   1303.825270   1930.111740    275.788500   2049.625820  1642.945280
# 10-6    784.487110   -236.063000   -811.693830   1971.212010  -754.490970
# 10-6   -561.681340   -320.036200   -540.875790   1225.788120  -825.595280
# 10-6    -79.561722   -330.249298  -1260.067261    224.326187  -736.488647
# 10-8  ...     0.443898    60.148800   152.187696  -122.210936    61.532752
# 10-8  ...   -47.243744   -21.839291   -71.420385   -52.302104     1.124928
# 10-8  ...   -26.765143   -92.984317  -120.768570   -88.723087   -24.533679
#
#       560.089844   557.230469   554.369141   551.507813   548.646484
# 10-6   238.195030  1067.456310 -1745.596420 -1126.572190          NaN
# 10-6   596.175330  1070.582620 -2959.949230  -845.668120          NaN
# 10-6  1476.614840  1289.664020 -2428.585140 -2015.723140          NaN
# 10-6   118.130010   794.885280  -965.419460   214.218540          NaN
# 10-6  -816.751282  -199.618912  -142.865067  -124.768097          NaN
# 10-9    19.248367    10.356694    25.728153   -10.310596     1.532385
# 10-9    52.142960    29.760458    14.654856    25.283457   -11.239206
# 10-9    15.012000    -2.132350    19.188300    10.455460   -16.088780
# 10-9   -54.513771    -4.613622   114.381668    21.902927   -45.525539
# 10-9   -12.758610    13.208550   -22.392450     5.181130    -0.109960
# 10-5   459.125246  -265.708027   666.674176   645.082274   275.196644
# 10-5  -844.629838 -1669.868573  -570.612403  -672.804287   135.999101
# 10-5   404.489738    77.423889   356.681303   434.931357    79.153548
# 10-5  -235.021156  -738.686959  -161.462322  -343.062694    -7.296946
# 10-5   381.813883   181.551689   696.450373   192.293776   853.390320
# 10-7  -106.425580  -367.108397   492.952088   303.039809   701.185069
# 10-7   -71.862548  -603.397495   182.401905   329.047403   351.171605
# 10-7  -675.043191  -528.107501  -489.830836  -182.524559   -77.977068
# 10-7  -177.124994  -840.686484   147.863420   876.085657   756.165797
# 10-7  -213.052638  -262.451161   207.315056   274.161986    68.483766
# 10-8    56.955935    99.319624    55.025221    47.938523  -136.599813
# 10-8    25.632610   -63.696529    -3.922598    74.243576   -27.958211
# 10-8    -5.100264   -93.074296   -54.133549    94.313688    63.257869
# 10-8   -11.270628    29.369366    67.756116   101.135237    83.173188
# 10-8    52.307890    21.667072    47.760594   175.227219   175.821724
#
# [25 rows x 472 columns]

# %%
#Get and Process Ag Rings Data Second Set

Source = "ESMA"
Chemical = "r6g(Ag Nano Rings 2)"

dfA2 = pd.DataFrame()
for j in [6,9]:
    Concentration = "10-" + str(j)
    for i in [1, 2, 3, 4, 5]:
        temp = me.GetSpectra(Source, Chemical, Concentration, str(i))
        temp.set_index("#Wave", inplace = True)
        targ_len = len(temp)
        temp = temp.transpose()
        temp = temp.rename({'#Intensity':Concentration}, axis = 0)
        temp.set_axis(np.array(range(targ_len)), axis =1, inplace = True)
        dfA2 = pd.concat([dfA2, temp], axis = 0)  
        
for j in [5,7,8]:
    Concentration = "10-" + str(j)
    for i in [1, 2, 3, 4, 5]:
        temp = me.GetSpectra(Source, Chemical, Concentration, str(i))
        temp.set_index("#Wave", inplace = True)
        temp = np.flip(signal.resample(temp, targ_len))
        temp = np.reshape(temp, [targ_len])
        temp = pd.DataFrame(temp)
        temp = temp.transpose()
        temp = temp.rename({0:Concentration}, axis = 0)
        temp.set_axis(np.array(range(targ_len)), axis =1, inplace = True)
        dfA2 = pd.concat([dfA2, temp], axis = 0) 
        
dfA2.set_axis(col_names, axis =1, inplace = True)
dfA2
# Out:
#       1800.529297  1798.058594  1795.587891  1793.115234   1790.642578  \
# 10-6 -1051.341431   330.191101  -107.819061   485.228729    280.002655
# 10-6  -933.227270    85.536780  -602.949520   281.157240   -628.860080
# 10-6 -1410.822750    46.968030  -341.634110   -99.162580   -351.616930
# 10-6   578.263611   672.665649  -433.932922    85.725266   -123.281952
# 10-6  -194.184630   841.462880  -859.920010   425.131920   -191.583080
# 10-9    -0.440075    57.848381   -16.363346    87.990692     16.293346
# 10-7  -170.892610  -147.697257  -223.637098   296.932750  -166.114230
# 10-8     0.224650    27.018200  -135.114720    41.528230    15.575990
# 10-8    -9.528380    95.275310   -29.194060    41.377750   -41.182510
# 10-8    10.367323   -14.655848   -20.017040   -35.161606    10.056053
# 10-8     5.435520    -0.116510     6.946090   -16.779540     5.977130
# 10-8     2.834992    67.673500     6.771304    -9.645350    25.550837
#
# [25 rows x 472 columns]

# %%
#Combine Datasets
df = pd.concat([dfO, dfA1, dfA2], axis = 0)
df = df.fillna(0)

# %%
#Perform Train Test Split

from sklearn.model_selection import train_test_split

[train, test] = train_test_split(df, random_state = 42, shuffle = True, train_size = 0.8)

y_tn = train.index
y_tt = test.index
X_tt = test.to_numpy()
X_tn = train.to_numpy()

# %%
#Scale Dataset

from sklearn.preprocessing import StandardScaler

Scale = StandardScaler()

X_tn = Scale.fit_transform(X_tn)
X_tt = Scale.transform(X_tt)

# %%
#Fit Classifiers and Predict Test Values.

LinClass = Perceptron()
LinClass.fit(X_tn, y_tn)
ypred = LinClass.predict(X_tt)

RFC = RandomForestClassifier(random_state = 42)
RFC.fit(X_tn, y_tn)
ypred = RFC.predict(X_tt)

SVC = LinearSVC(max_iter = 10000, random_state = 42)
SVC.fit(X_tn, y_tn)
ypred = SVC.predict(X_tt)

KNN = KNeighborsClassifier()
KNN.fit(X_tn, y_tn)
ypred = KNN.predict(X_tt)

# %%
#Calculate Cross Validation Scores
from sklearn.model_selection import cross_val_score

df.columns = df.columns.astype(str)

X_ = np.append(X_tn, X_tt, axis = 0)
y = np.append(y_tn, y_tt)

RFCscore = cross_val_score(RFC, X_, y)
display("Random Forest Cross Validation")
display(RFCscore)
display(np.mean(RFCscore))

SVCscore = cross_val_score(SVC, X_, y)
display("Support Vector Cross Validation")
display(SVCscore)
display(np.mean(SVCscore))

KNCscore = cross_val_score(KNN, X_, y)
display("K-Neighbors Cross Validation")
display(KNCscore)
display(np.mean(KNCscore))
# Out:
# 'Random Forest Cross Validation'
# array([0.82608696, 0.95652174, 0.82608696, 0.73913043, 0.91304348])
# 0.8521739130434781
# C:\Users\KNU-LIFE\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 'Support Vector Cross Validation'
# array([0.69565217, 0.73913043, 0.7826087 , 0.73913043, 0.73913043])
# 0.7391304347826086
# 'K-Neighbors Cross Validation'
# array([0.60869565, 0.86956522, 0.91304348, 0.73913043, 0.82608696])
# 0.7913043478260869

# %%
#Apply Fourier Transform to Training and Testing Data
#Fourier Transform Performs Best Without Scaling
X_tt = test.to_numpy()
X_tn = train.to_numpy()

X_tnf = np.fft.fft(X_tn)
X_ttf = np.fft.fft(X_tt)

#Data is stored as columns of all real values followed by columns of all imaginary values.
X_tnf = np.append(np.real(X_tnf), np.imag(X_tnf), axis = 1)
X_ttf = np.append(np.real(X_ttf), np.imag(X_ttf), axis = 1)

plt.figure()
plt.plot(X_tnf[1, :])
plt.figure()
plt.plot(X_tnf[7, :]);

# %%
#Fit Classifiers and Predict Test Values.

LinClass = Perceptron()
LinClass.fit(X_tnf, y_tn)
ypred = LinClass.predict(X_ttf)

RFC = RandomForestClassifier(random_state = 42)
RFC.fit(X_tnf, y_tn)
ypred = RFC.predict(X_ttf)

SVC = LinearSVC(max_iter = 10000, random_state = 42)
SVC.fit(X_tnf, y_tn)
ypred = SVC.predict(X_ttf)

KNN = KNeighborsClassifier()
KNN.fit(X_tnf, y_tn)
ypred = KNN.predict(X_ttf)

# %%
#Calculate Cross Validation Scores
from sklearn.model_selection import cross_val_score

df.columns = df.columns.astype(str)

X_f = np.append(X_tnf, X_ttf, axis = 0)
y = np.append(y_tn, y_tt)

RFCscore = cross_val_score(RFC, X_f, y)
display("Random Forest Cross Validation")
display(RFCscore)
display(np.mean(RFCscore))

SVCscore = cross_val_score(SVC, X_f, y)
display("Support Vector Cross Validation")
display(SVCscore)
display(np.mean(SVCscore))

KNCscore = cross_val_score(KNN, X_f, y)
display("K-Neighbors Cross Validation")
display(KNCscore)
display(np.mean(KNCscore))
# Out:
# 'Random Forest Cross Validation'
# array([0.82608696, 0.91304348, 0.86956522, 0.95652174, 0.91304348])
# 0.8956521739130434
# C:\Users\KNU-LIFE\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 'Support Vector Cross Validation'
# array([0.7826087 , 0.73913043, 0.73913043, 0.86956522, 0.7826087 ])
# 0.782608695652174
# 'K-Neighbors Cross Validation'
# array([0.56521739, 0.52173913, 0.60869565, 0.56521739, 0.56521739])
# 0.5652173913043478

# %%
#Apply Welsh-Hadamard Transform to Training and Testing Data
from sympy.discrete.transforms import fwht, ifwht
X_tt = test.to_numpy()
X_tn = train.to_numpy()

X_tnh = np.apply_along_axis(fwht, axis=1, arr=X_tn)
X_tth = np.apply_along_axis(fwht, axis=1, arr=X_tt)

plt.figure()
plt.plot(X_tnh[1, :])
plt.figure()
plt.plot(X_tnh[7, :]);

# %%
#Fit Classifiers and Predict Test Values.

LinClass = Perceptron()
LinClass.fit(X_tnh, y_tn)
ypred = LinClass.predict(X_tth)

RFC = RandomForestClassifier(random_state = 42)
RFC.fit(X_tnh, y_tn)
ypred = RFC.predict(X_tth)

SVC = LinearSVC(max_iter = 10000, random_state = 42)
SVC.fit(X_tnh, y_tn)
ypred = SVC.predict(X_tth)

KNN = KNeighborsClassifier()
KNN.fit(X_tnh, y_tn)
ypred = KNN.predict(X_tth)
# Out:
# C:\Users\KNU-LIFE\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(

# %%
#Calculate Cross Validation Scores
from sklearn.model_selection import cross_val_score

df.columns = df.columns.astype(str)

X_h = np.append(X_tnh, X_tth, axis = 0)
y = np.append(y_tn, y_tt)

RFCscore = cross_val_score(RFC, X_h,y)
display("Random Forest Cross Validation")
display(RFCscore)
display(np.mean(RFCscore))

SVCscore = cross_val_score(SVC, X_h, y)
display("Support Vector Cross Validation")
display(SVCscore)
display(np.mean(SVCscore))

KNCscore = cross_val_score(KNN, X_h, y)
display("K-Neighbors Cross Validation")
display(KNCscore)
display(np.mean(KNCscore))
# Out:
# 'Random Forest Cross Validation'
# array([0.91304348, 0.91304348, 0.86956522, 0.95652174, 0.95652174])
# 0.9217391304347826
# C:\Users\KNU-LIFE\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\KNU-LIFE\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\KNU-LIFE\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\KNU-LIFE\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\KNU-LIFE\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 'Support Vector Cross Validation'
# array([0.86956522, 0.95652174, 0.69565217, 0.7826087 , 0.91304348])
# 0.8434782608695652
# 'K-Neighbors Cross Validation'
# array([0.65217391, 0.91304348, 0.82608696, 0.69565217, 0.82608696])
# 0.782608695652174
