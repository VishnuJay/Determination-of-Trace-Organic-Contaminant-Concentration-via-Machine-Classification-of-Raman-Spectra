# %%
import pandas as pd
import numpy as np
from scipy import stats as stats
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import Perceptron
from sklearn.svm import LinearSVC
import KeyFunctions as me
RandState = 117

# %%
from sklearn.model_selection import train_test_split

#Import Full R6g Dataset
df, labels = me.ConstructCombinedDataset()

[train, test] = train_test_split(df, random_state = RandState, shuffle = True, train_size = 0.8)

y_tn = train.index
y_tt = test.index
X_tt = test.to_numpy()
X_tn = train.to_numpy()
col_names = df.columns
display(labels)
# Out:
# ['10-5', '10-6', '10-7', '10-8', '10-9', '10-11', '10-14', '10-16']

# %%
from sklearn.preprocessing import StandardScaler

Scale = StandardScaler()

X_tn = Scale.fit_transform(X_tn)
X_tt = Scale.transform(X_tt)

# %%
import matplotlib.ticker as mticker

tempR6g = pd.DataFrame(X_tn, index = y_tn, columns = col_names)
corr = tempR6g.corr(method = 'spearman')
thresh = abs(corr)>0.75

stwave = max(df.columns)
endwave = min(df.columns)

fig = plt.pcolormesh(corr, figure = plt.figure(figsize = [6.5, 6]));
plt.colorbar(label = 'Correlation Coefficient');
ax = plt.gca()
ax.set_title('');
ax.set_xlabel("Wave Number")
ax.set_ylabel("Wave Number")
ax.xaxis.set_label_position('top')

ticks_loc = np.linspace(0, np.shape(df)[1], 6)
ax.yaxis.set_major_locator(mticker.FixedLocator(ticks_loc))
ax.xaxis.set_major_locator(mticker.FixedLocator(ticks_loc))
ticklbls = np.linspace(stwave, endwave, 6)
ticklbls = ticklbls.astype(int)
ax.set_xticklabels(ticklbls)
ax.set_yticklabels(ticklbls)
plt.gca().invert_yaxis()
ax.xaxis.tick_top()

fz = np.arctanh(corr)
fz[fz == np.inf] = np.nan
fzavg = np.nanmean(fz)
ravg = np.tanh(fzavg)
ravg = round(ravg, 4)
plt.annotate('Average Correlation Coefficient = ' + str(ravg), [0.125, 0.055], xycoords = 'figure fraction', fontsize = 15, fontweight = 'bold');
plt.savefig("Tables and Figures/SVG Files/R6g Correlation Plot.svg", format = "svg", bbox_inches='tight')
plt.savefig("Tables and Figures/PNG Files/R6g Correlation Plot.png", format = "png", bbox_inches='tight')
# Out:
# C:\Users\jayapra1\Anaconda3\envs\Base\lib\site-packages\pandas\core\internals\blocks.py:402: RuntimeWarning: divide by zero encountered in arctanh
#   result = func(self.values, **kwargs)

# %%
display(corr.iloc[450, :].sort_values(ascending = False).iloc[0:20])
corr.index.get_loc(1382.716797)
# Out:
# 608.554688     1.000000
# 611.398438     0.975926
# 614.240234     0.970824
# 605.712891     0.968420
# 602.867188     0.941278
# 617.080078     0.929334
# 619.919922     0.905013
# 1180.400391    0.904473
# 1645.968750    0.903934
# 1572.681641    0.897800
# 1648.484375    0.896767
# 1575.218750    0.890741
# 1570.142578    0.890525
# 1577.755859    0.885732
# 600.021484     0.884730
# 1382.716797    0.884453
# 763.517578     0.880630
# 766.308594     0.879829
# 1183.060547    0.879490
# 1185.718750    0.878688
# Name: 608.554688, dtype: float64
# 165

# %%
fz = np.arctanh(corr)
fz[fz == np.inf] = np.nan
fzavg = np.nanmean(fz, axis = 1)
ravg = np.tanh(fzavg)

plt.plot(corr.columns, ravg, marker = '.',  figure = plt.figure(figsize = [14, 10]));
plt.plot(corr.columns, np.ones((len(corr.columns),1))*np.nanmean(ravg), 'r')
plt.ylabel("Average Correlation Coefficient")
plt.xlabel("Wave Number");
plt.legend(["Wave Number Average", "Overall Average"]);

# %%
from sklearn.decomposition import PCA

pd.options.display.float_format = '{:.2f}'.format

PCs = PCA(whiten = True)
PCs.fit(X_tn)
X_tnred = PCs.transform(X_tn)
X_ttred = PCs.transform(X_tt)
display(np.shape(PCs.components_))
# Out:
# (92, 472)

# %%
from sklearn.model_selection import train_test_split

#Import Full Triclosan Dataset
df, labels = me.ConstructCombinedTriclosanDataset()

[train, test] = train_test_split(df, random_state = RandState, shuffle = True, train_size = 0.8)

y_tn = train.index
y_tt = test.index
X_tt = test.to_numpy()
X_tn = train.to_numpy()
col_names = df.columns
display(labels)
# Out:
# ['10-3', '10-4', '10-5', '10-7', '10-8', '10-9']

# %%
Scale = StandardScaler()

X_tn = Scale.fit_transform(X_tn)
X_tt = Scale.transform(X_tt)

# %%
tempTri = pd.DataFrame(X_tn, index = y_tn, columns = col_names)
corr = tempTri.corr(method = 'spearman')
thresh = abs(corr)>0.75

stwave = min(df.columns)
endwave = max(df.columns)

fig = plt.pcolormesh(corr, figure = plt.figure(figsize = [6.5, 6]));
plt.colorbar(label = 'Correlation Coefficient');
ax = plt.gca()
ax.set_title('');
ax.set_xlabel("Wave Number")
ax.set_ylabel("Wave Number")
ax.xaxis.set_label_position('top')

ticks_loc = np.linspace(0, np.shape(df)[1], 6)
ax.yaxis.set_major_locator(mticker.FixedLocator(ticks_loc))
ax.xaxis.set_major_locator(mticker.FixedLocator(ticks_loc))
ticklbls = np.linspace(stwave, endwave, 6)
ticklbls = ticklbls.astype(int)
ax.set_xticklabels(ticklbls)
ax.set_yticklabels(ticklbls)
plt.gca().invert_yaxis()
ax.xaxis.tick_top()

fz = np.arctanh(corr)
fz[fz == np.inf] = np.nan
fzavg = np.nanmean(np.nanmean(fz))
ravg = np.tanh(fzavg)
ravg = round(ravg, 4)
plt.annotate('Average Correlation Coefficient = ' + str(ravg), [0.125, 0.055], xycoords = 'figure fraction', fontsize = 15, fontweight = 'bold');
plt.savefig("Tables and Figures/SVG Files/Triclosan Correlation Plot.svg", format = "svg", bbox_inches='tight')
plt.savefig("Tables and Figures/PNG Files/Triclosan Correlation Plot.png", format = "png", bbox_inches='tight')
# Out:
# C:\Users\jayapra1\Anaconda3\envs\Base\lib\site-packages\pandas\core\internals\blocks.py:402: RuntimeWarning: divide by zero encountered in arctanh
#   result = func(self.values, **kwargs)

# %%
#Import Full R6g Dataset
df, labels = me.ConstructCombinedChlorDataset()

[train, test] = train_test_split(df, random_state = RandState, shuffle = True, train_size = 0.8)

y_tn = train.index
y_tt = test.index
X_tt = test.to_numpy()
X_tn = train.to_numpy()
col_names = df.columns
display(labels)
# Out:
# ['10-3', '10-4', '10-5', '10-6', '10-7']

# %%
Scale = StandardScaler()

X_tn = Scale.fit_transform(X_tn)
X_tt = Scale.transform(X_tt)

# %%
tempChlor = pd.DataFrame(X_tn, index = y_tn, columns = col_names)
corr = tempChlor.corr(method = 'spearman')
thresh = abs(corr)>0.75

stwave = max(df.columns)
endwave = min(df.columns)

fig = plt.pcolormesh(corr, figure = plt.figure(figsize = [6.5, 6]));
plt.colorbar(label = 'Correlation Coefficient');
ax = plt.gca()
ax.set_title('');
ax.set_xlabel("Wave Number")
ax.set_ylabel("Wave Number")
ax.xaxis.set_label_position('top')

ticks_loc = np.linspace(0, np.shape(df)[1], 6)
ax.yaxis.set_major_locator(mticker.FixedLocator(ticks_loc))
ax.xaxis.set_major_locator(mticker.FixedLocator(ticks_loc))
ticklbls = np.linspace(stwave, endwave, 6)
ticklbls = ticklbls.astype(int)
ax.set_xticklabels(ticklbls)
ax.set_yticklabels(ticklbls)
plt.gca().invert_yaxis()
ax.xaxis.tick_top()

fz = np.arctanh(corr)
fz[fz == np.inf] = np.nan
fzavg = np.nanmean(fz)
ravg = np.tanh(fzavg)
ravg = round(ravg, 4)
plt.annotate('Average Correlation Coefficient = ' + str(ravg), [0.125, 0.055], xycoords = 'figure fraction', fontsize = 15, fontweight = 'bold');
plt.savefig("Tables and Figures/SVG Files/Chlorpyrifos Correlation Plot.svg", format = "svg", bbox_inches='tight')
plt.savefig("Tables and Figures/PNG Files/Chlorpyrifos Correlation Plot.png", format = "png", bbox_inches='tight')
# Out:
# C:\Users\jayapra1\Anaconda3\envs\Base\lib\site-packages\pandas\core\internals\blocks.py:402: RuntimeWarning: divide by zero encountered in arctanh
#   result = func(self.values, **kwargs)

# %%
fig, ax = plt.subplots(1, 3, figsize = [20, 8])

font = {'size'   : 14,
       'weight' : 'bold'}

plt.rc('font', **font)


#R6g
corrR6g = tempR6g.corr(method = 'spearman')

stwave = max(tempR6g.columns)
endwave = min(tempR6g.columns)

cb = ax[0].pcolormesh(corrR6g, vmin = -1, vmax = 1);
ax[0].set_title('R6g', size = 20);
ax[0].set_xlabel("Wave Number")
ax[0].set_ylabel("Wave Number")
ax[0].xaxis.set_label_position('top')

ticks_loc = np.linspace(0, np.shape(corrR6g)[0], 6)
ax[0].yaxis.set_major_locator(mticker.FixedLocator(ticks_loc))
ax[0].xaxis.set_major_locator(mticker.FixedLocator(ticks_loc))
ticklbls = np.linspace(stwave, endwave, 6)
ticklbls = ticklbls.astype(int)
ax[0].set_xticklabels(ticklbls)
ax[0].set_yticklabels(ticklbls)
ax[0].invert_yaxis()
ax[0].xaxis.tick_top()

fz = np.arctanh(corrR6g)
fz[fz == np.inf] = np.nan
fzavg = np.nanmean(fz)
ravg = np.tanh(fzavg)
ravg = round(ravg, 4)
ax[0].annotate('Average Spearman Correlation Coefficient = ' + str(ravg), [0.065, 0.225], xycoords = 'figure fraction', fontsize = 12);

#Triclosan
corrTri = tempTri.corr(method = 'spearman')
stwave = max(tempTri.columns)
endwave = min(tempTri.columns)

ax[1].pcolormesh(corrTri, vmin = -1, vmax = 1);
ax[1].set_title('Triclosan', size = 20);
ax[1].set_xlabel("Wave Number")
ax[1].set_ylabel("")
ax[1].xaxis.set_label_position('top')

ticks_loc = np.linspace(0, np.shape(corrTri)[1], 6)
ax[1].yaxis.set_major_locator(mticker.FixedLocator(ticks_loc))
ax[1].xaxis.set_major_locator(mticker.FixedLocator(ticks_loc))
ticklbls = np.linspace(stwave, endwave, 6)
ticklbls = ticklbls.astype(int)
ax[1].set_xticklabels(ticklbls)
ax[1].set_yticklabels(ticklbls)
ax[1].invert_yaxis()
ax[1].xaxis.tick_top()

fz = np.arctanh(corrTri)
fz[fz == np.inf] = np.nan
fzavg = np.nanmean(np.nanmean(fz))
ravg = np.tanh(fzavg)
ravg = round(ravg, 4)
ax[1].annotate('Average Spearman Correlation Coefficient = ' + str(ravg), [0.34, 0.225], xycoords = 'figure fraction', fontsize = 12);

#Chlorpyrifos
corrChlor = tempChlor.corr(method = 'spearman')
thresh = abs(corr)>0.75

stwave = max(tempChlor.columns)
endwave = min(tempChlor.columns)

ax[2].pcolormesh(corrChlor, vmin = -1, vmax = 1);
ax[2].set_title('Chlorpyrifos', size = 20);
ax[2].set_xlabel("Wave Number")
ax[2].set_ylabel("")
ax[2].xaxis.set_label_position('top')

ticks_loc = np.linspace(0, np.shape(corrChlor)[1], 6)
ax[2].yaxis.set_major_locator(mticker.FixedLocator(ticks_loc))
ax[2].xaxis.set_major_locator(mticker.FixedLocator(ticks_loc))
ticklbls = np.linspace(stwave, endwave, 6)
ticklbls = ticklbls.astype(int)
ax[2].set_xticklabels(ticklbls)
ax[2].set_yticklabels(ticklbls)
ax[2].invert_yaxis()
ax[2].xaxis.tick_top()

fz = np.arctanh(corrChlor)
fz[fz == np.inf] = np.nan
fzavg = np.nanmean(fz)
ravg = np.tanh(fzavg)
ravg = round(ravg, 4)
ax[2].annotate('Average Spearman Correlation Coefficient = ' + str(ravg), [0.615, 0.225], xycoords = 'figure fraction', fontsize = 12);

fig.colorbar(cb, ax = ax[:], location = 'bottom', label = 'Correlation Coefficient');
plt.savefig("Tables and Figures/SVG Files/Correlation Plots.svg", format = "svg", bbox_inches='tight')
plt.savefig("Tables and Figures/PNG Files/Correlation Plots.png", format = "png", bbox_inches='tight')
